# %%
# %matplotlib inline
import numpy as np
from scipy.integrate import cumtrapz
import matplotlib.pyplot as plt
from pylag import *

# %%
nx = 64
a = np.arange(0,nx,dtype=np.float32)
#x = a
#v = np.exp(-(a-50)**2/2/5**2)*0.1
x = np.concatenate(([0],cumtrapz(1 - np.exp(-(a-(nx-1)/2.)**2/2/5**2)*0.1)))
#x = a + np.sin(a/(nx-1)*np.pi*2)
v = np.zeros((nx,),dtype=np.float32)
T = np.ones((nx,),dtype=np.float32)

t = 0.
dt = 0.1

for i in range(0,int(1e2)):
    step(dt,t,x,v,T,f)

plt.figure(figsize = (16,5))
plt.subplot(121)
plt.plot(x,1/d(x))
plt.subplot(122)
plt.plot(x,v)

np.sum(T)
# Out:
# 64.0

# %%
x
# Out:
# array([  2.02444394e-04,   9.99797556e-01,   1.99931436e+00,
#          2.99857903e+00,   3.99736450e+00,   4.99535335e+00,
#          5.99210123e+00,   6.98700641e+00,   7.97929251e+00,
#          8.96801742e+00,   9.95213059e+00,   1.09305994e+01,
#          1.19026066e+01,   1.28678065e+01,   1.38265638e+01,
#          1.47800513e+01,   1.57301256e+01,   1.66790093e+01,
#          1.76289099e+01,   1.85817210e+01,   1.95388727e+01,
#          2.05012937e+01,   2.14694378e+01,   2.24433443e+01,
#          2.34227116e+01,   2.44069870e+01,   2.53954555e+01,
#          2.63873232e+01,   2.73818001e+01,   2.83781597e+01,
#          2.93757658e+01,   3.03740740e+01,   3.13726081e+01,
#          3.23709170e+01,   3.33685233e+01,   3.43648827e+01,
#          3.53593607e+01,   3.63512289e+01,   3.73396969e+01,
#          3.83239748e+01,   3.93033422e+01,   4.02772481e+01,
#          4.12453923e+01,   4.22078139e+01,   4.31649668e+01,
# ...

# %%
plt.plot(x,T)

# %%
76*1.2
# Out:
# 91.2
